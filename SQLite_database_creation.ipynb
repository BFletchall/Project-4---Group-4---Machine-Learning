# %% [markdown]
# # Project 4
#
# - One cleaned csv file was provided containing time segment information for fabricated steel assemblies.
# ---

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
from sqlalchemy import create_engine

# %%
# Read the combined data CSV file
combined_df = pd.read_csv('data/combined_data.csv')
combined_df.head()
# Out:
#   NumberWithDash  EPM_ProductionControlItemID EPM_MainMark  \
# 0         19-048                       870038         T124
# 1         19-048                       870040         T125
# 2         19-048                       870040         T125
# 3         19-048                       870040         T125
# 4         19-048                       870040         T125
#
#    EPM_InstanceNumber Assembly_MainPieceProductionCode  \
# 0                   1                  S.S. TUBE STEEL
# 1                   1                  S.S. TUBE STEEL
# 2                   1                  S.S. TUBE STEEL
# 3                   2                  S.S. TUBE STEEL
# 4                   2                  S.S. TUBE STEEL
#
#    Assembly_MainPartLengthFt  Assembly_WeightEachLbs  \
# 0                       2.81                  39.575
# 1                       7.91                 112.116
# 2                       7.91                 112.116
# 3                       7.91                 112.116
# ...

# %%
# Create SQLAlchemy engine
engine = create_engine('sqlite:///claimed_time.db')
# Connect to the database
conn = engine.connect()

# %%
# Save the DataFrame to a table in the database
combined_df.to_sql('claimed_table', con=conn, if_exists='replace', index=False)
# Out:
# 8407

# %%
# Query all records in the database
claimed_df = pd.read_sql("Select * from claimed_table", conn)
claimed_df
# Out:
#      NumberWithDash  EPM_ProductionControlItemID EPM_MainMark  \
# 0            19-048                       870038         T124
# 1            19-048                       870040         T125
# 2            19-048                       870040         T125
# 3            19-048                       870040         T125
# 4            19-048                       870040         T125
# ...             ...                          ...          ...
# 8402         24-500                       876966        HR103
# 8403         24-500                       876966        HR103
# 8404         24-500                       876966        HR103
# 8405         24-500                       904279         S73A
# 8406         24-500                       904279         S73A
#
#       EPM_InstanceNumber Assembly_MainPieceProductionCode  \
# 0                      1                  S.S. TUBE STEEL
# 1                      1                  S.S. TUBE STEEL
# ...
